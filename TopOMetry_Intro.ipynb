# %% [markdown]
# # Analyzing PBMCs single-cell data with TopOMetry

# %% [markdown]
# For the manuscript

# %%
# Install pre-requisites and dbmap (for comparisons)
# !pip install nmslib annoy scipy scanpy numba kneed pymde python-igraph leidenalg dbmap
# Out:
# Requirement already satisfied: nmslib in /usr/local/lib/python3.7/dist-packages (2.1.1)
# Requirement already satisfied: annoy in /usr/local/lib/python3.7/dist-packages (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: scanpy in /usr/local/lib/python3.7/dist-packages (1.7.2)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (0.51.2)
# Requirement already satisfied: kneed in /usr/local/lib/python3.7/dist-packages (0.7.0)
# Requirement already satisfied: pymde in /usr/local/lib/python3.7/dist-packages (0.1.8)
# Requirement already satisfied: python-igraph in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: leidenalg in /usr/local/lib/python3.7/dist-packages (0.8.4)
# Requirement already satisfied: dbmap in /usr/local/lib/python3.7/dist-packages (1.2.0.4)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib) (2.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib) (5.4.8)
# Requirement already satisfied: numpy>=1.10.0; python_version >= "3.5" in /usr/local/lib/python3.7/dist-packages (from nmslib) (1.19.5)
# Requirement already satisfied: natsort in /usr/local/lib/python3.7/dist-packages (from scanpy) (5.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from scanpy) (20.9)
# Requirement already satisfied: h5py>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from scanpy) (2.10.0)
# Requirement already satisfied: statsmodels>=0.10.0rc2 in /usr/local/lib/python3.7/dist-packages (from scanpy) (0.10.2)
# Requirement already satisfied: sinfo in /usr/local/lib/python3.7/dist-packages (from scanpy) (0.3.1)
# Requirement already satisfied: anndata>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from scanpy) (0.7.6)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from scanpy) (1.1.5)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.7/dist-packages (from scanpy) (3.2.2)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from scanpy) (3.4.4)
# Requirement already satisfied: importlib-metadata>=0.7; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from scanpy) (3.10.1)
# Requirement already satisfied: networkx>=2.3 in /usr/local/lib/python3.7/dist-packages (from scanpy) (2.5.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from scanpy) (1.0.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.7/dist-packages (from scanpy) (0.11.1)
# Requirement already satisfied: patsy in /usr/local/lib/python3.7/dist-packages (from scanpy) (0.5.1)
# Requirement already satisfied: umap-learn>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from scanpy) (0.5.1)
# Requirement already satisfied: scikit-learn>=0.21.2 in /usr/local/lib/python3.7/dist-packages (from scanpy) (0.22.2.post1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from scanpy) (4.41.1)
# Requirement already satisfied: legacy-api-wrap in /usr/local/lib/python3.7/dist-packages (from scanpy) (1.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba) (54.2.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from pymde) (1.8.1+cu101)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from pymde) (0.9.1+cu101)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pymde) (2.23.0)
# Requirement already satisfied: pynndescent in /usr/local/lib/python3.7/dist-packages (from pymde) (0.5.2)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from python-igraph) (1.6.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->scanpy) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py>=2.10.0->scanpy) (1.15.0)
# Requirement already satisfied: stdlib-list in /usr/local/lib/python3.7/dist-packages (from sinfo->scanpy) (0.8.0)
# Requirement already satisfied: xlrd<2.0 in /usr/local/lib/python3.7/dist-packages (from anndata>=0.7.4->scanpy) (1.1.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->scanpy) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->scanpy) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.1.2->scanpy) (0.10.0)
# Requirement already satisfied: numexpr>=2.5.2 in /usr/local/lib/python3.7/dist-packages (from tables->scanpy) (2.7.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.7; python_version < "3.8"->scanpy) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.7; python_version < "3.8"->scanpy) (3.7.4.3)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.3->scanpy) (4.4.2)
# Requirement already satisfied: get-version>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from legacy-api-wrap->scanpy) (2.1)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.8.2->pymde) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pymde) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pymde) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pymde) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pymde) (2.10)

# %%
# Install pre-release of TopOMetry
# !pip install -i https://test.pypi.org/simple/ topo
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting topo
#   Downloading https://test-files.pythonhosted.org/packages/58/03/a4556c83c0ba425a814896684772ea30dda2c259ad6f7fa3b0967b8442c2/topo-0.4.0.8.1-py3-none-any.whl (96kB)
#      |████████████████████████████████| 102kB 2.7MB/s
# Installing collected packages: topo
# Successfully installed topo-0.4.0.8.1

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import dbmap as dm
import topo as tp
# Out:
# None
# None
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=120, dpi_save=800, facecolor='white', format='tif')
# Out:
# scanpy==1.7.2 anndata==0.7.6 umap==0.5.1 numpy==1.19.5 scipy==1.4.1 pandas==1.1.5 scikit-learn==0.22.2.post1 statsmodels==0.10.2 python-igraph==0.9.1

# %% [markdown]
# ## Analyzing ~33,000 PBMCs

# %% [markdown]
# ### Load data and QC

# %%
# !mkdir data
# !wget https://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc33k/pbmc33k_filtered_gene_bc_matrices.tar.gz -O data/pbmc33k_filtered_gene_bc_matrices.tar.gz
# !cd data; tar -xzf pbmc33k_filtered_gene_bc_matrices.tar.gz
# !mkdir write
# Out:
# --2021-04-18 19:59:20--  https://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc33k/pbmc33k_filtered_gene_bc_matrices.tar.gz
# Resolving cf.10xgenomics.com (cf.10xgenomics.com)... 104.18.1.173, 104.18.0.173, 2606:4700::6812:1ad, ...
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83082472 (79M) [application/x-tar]
# Saving to: ‘data/pbmc33k_filtered_gene_bc_matrices.tar.gz’
#
# data/pbmc33k_filter 100%[===================>]  79.23M  22.5MB/s    in 3.7s
#
# 2021-04-18 19:59:24 (21.4 MB/s) - ‘data/pbmc33k_filtered_gene_bc_matrices.tar.gz’ saved [83082472/83082472]

# %%
results_file = 'write/pbmc33k.h5ad'  # the file that will store the analysis results

# %%
adata = sc.read_10x_mtx(
    'data/filtered_gene_bc_matrices/hg19/',  
    var_names='gene_symbols',               
    cache=True)          
adata.var_names_make_unique()
adata
# Out:
# ... writing an h5ad cache file to speedup reading next time
# AnnData object with n_obs × n_vars = 33148 × 32738
#     var: 'gene_ids'

# %%
# Default QC
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
adata
# Out:
# filtered out 7 cells that have less than 200 genes expressed
# filtered out 14795 genes that are detected in less than 3 cells
# AnnData object with n_obs × n_vars = 33141 × 17943
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# ### Default workflow

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=8, min_disp=0.3)
sc.pl.highly_variable_genes(adata)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
adata.raw = adata
adata = adata[:, adata.var.highly_variable]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 33141 × 3322
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'hvg'

# %%
sc.pp.scale(adata, max_value=10)
sc.tl.pca(adata)
sc.pl.pca_variance_ratio(adata, log=True, save='_PCA_log_variance_ratio')
# Out:
# /usr/local/lib/python3.7/dist-packages/scanpy/preprocessing/_simple.py:845: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:46)
# WARNING: saving figure to file figures/pca_variance_ratio_PCA_log_variance_ratio.tif

# %%
sc.pp.neighbors(adata)
sc.tl.leiden(adata)
sc.tl.umap(adata)
sc.pl.embedding(adata, basis='umap', color=['leiden'], size=5)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:05)
# running Leiden clustering
#     finished: found 14 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:08)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:44)

# %%
sc.pl.embedding(adata, basis='umap', color=['CD4', 'CD8A', 'CTSL', 'PF4', 'GZMK', 'MS4A1'], size=5, ncols=3)

# %% [markdown]
# ### Topological analysis with TopOMetry

# %%
adata.write_h5ad(results_file)
adata = sc.read_h5ad(results_file)
adata
# Out:
# AnnData object with n_obs × n_vars = 33141 × 3322
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
# Fit topological model
tg = tp.models.TopoGraph(n_jobs=10, n_eigs=150,
  		  plot_spectrum=True
  		  ).fit(adata.X)
dgraph, dtgraph = tg.transform()
# Out:
# Building topological basis...
# Diffusion fitted in = 1734.929031 (sec)
# Building diffusion graph...
# Topological graphs extracted in = 65.527704 (sec)

# %%
# Rescale to 50 components
tg.MSDiffMap = tg.DiffBasis.rescale(n_eigs=150)

adata.obsm['X_db'] = tg.MSDiffMap

# %%
# Layout optimization
embdt, aux = tp.models.MAP(tg.MSDiffMap, dtgraph, min_dist=0.3, spread=2, n_epochs=600)

adata.obsm['X_db_dtMAP'] = embdt
# Out:
# Fuzzy layout optimization embedding in = 44.389385 (sec)

# %%
sc.pl.embedding(adata, basis='db_dtMAP', color=['leiden'], edges=False, size=5)

# %%
sc.pl.embedding(adata, basis='db_dtMAP', color=['CD4', 'CD8A', 'CTSL', 'PF4', 'GZMK', 'MS4A1'], size=5, ncols=3)

# %%
# We can also optimize the layout using the vanilla UMAP approach
import umap
db_umap_emb = umap.UMAP(min_dist=0.3, n_epochs=600).fit_transform(tg.MSDiffMap)
adata.obsm['X_db_UMAP'] = db_umap_emb

# %%
sc.pl.embedding(adata, basis='db_UMAP', color=['leiden'], edges=False, size=5)

# %% [markdown]
# ## Using pyMDE for minimum-distortion embeddings of the topological graphs

# %%
import pymde

# %%
# First a neighborhood preserving embedding on the diffusion basis
nbr_mde = pymde.preserve_neighbors(tg.MSDiffMap, verbose=True)
nbr_embedding = nbr_mde.embed(verbose=True)
pymde.plot(nbr_embedding, color_by=adata.obs['leiden'], axis_limits=(7.5,-7.5))
# Out:
# Apr 18 09:44:29 PM: Computing 15-nearest neighbors, with max_distance=None
# Sun Apr 18 21:44:30 2021 Building RP forest with 18 trees
# Sun Apr 18 21:44:31 2021 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Apr 18 09:44:36 PM: Computing quadratic initialization.
# Apr 18 09:45:31 PM: Fitting a centered embedding into R^2, for a graph with 33141 items and 913918 edges.
# Apr 18 09:45:31 PM: `embed` method parameters: eps=1.0e-05, max_iter=300, memory_size=10
# Apr 18 09:45:31 PM: iteration 000 | distortion 1.586110 | residual norm 2.44895 | step length 0.00310821 | percent change 0.00295687
# Apr 18 09:45:38 PM: iteration 030 | distortion 0.283906 | residual norm 0.00249407 | step length 1 | percent change 1.2377
# Apr 18 09:45:46 PM: iteration 060 | distortion 0.223668 | residual norm 0.00123309 | step length 1 | percent change 0.635365
# Apr 18 09:45:53 PM: iteration 090 | distortion 0.208214 | residual norm 0.000660527 | step length 1 | percent change 0.410464
# Apr 18 09:45:59 PM: iteration 120 | distortion 0.201979 | residual norm 0.000395697 | step length 1 | percent change 0.223161
# Apr 18 09:46:07 PM: iteration 150 | distortion 0.199039 | residual norm 0.000272221 | step length 1 | percent change 0.192759
# Apr 18 09:46:13 PM: iteration 180 | distortion 0.197093 | residual norm 0.000234997 | step length 1 | percent change 0.157983
# Apr 18 09:46:20 PM: iteration 210 | distortion 0.195706 | residual norm 0.00020471 | step length 1 | percent change 0.0547608
# Apr 18 09:46:27 PM: iteration 240 | distortion 0.194838 | residual norm 0.0001807 | step length 1 | percent change 0.238341
# Apr 18 09:46:34 PM: iteration 270 | distortion 0.194214 | residual norm 0.000169713 | step length 1 | percent change 0.296651
# Apr 18 09:46:41 PM: iteration 299 | distortion 0.193672 | residual norm 0.00015151 | step length 1 | percent change 0.192296
# Apr 18 09:46:41 PM: Finished fitting in 69.713 seconds and 300 iterations.
# Apr 18 09:46:41 PM: average distortion 0.194 | residual norm 1.5e-04

# %%
# Now preserving distances
dist_mde = pymde.preserve_distances(tg.MSDiffMap, verbose=True)
dist_embedding = dist_mde.embed()
pymde.plot(dist_embedding, color_by=adata.obs['leiden'], axis_limits=(10,-10))
# Out:
# Apr 18 09:49:56 PM: Sampling 50000000 edges
# Apr 18 09:50:03 PM: Computing 50000000 distances
